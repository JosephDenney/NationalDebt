# %%
import pandas as pd
import numpy as np

# %%
us_debt_by_day = pd.read_csv("DebtPenny_10_years.csv",index_col='Calendar Day Number')

# %%
us_debt_by_day
# Out:
#                     Record Date  Debt Held by the Public  \
# Calendar Day Number
# 28                   2021-05-28             2.202094e+13
# 27                   2021-05-27             2.198369e+13
# 26                   2021-05-26             2.200589e+13
# 25                   2021-05-25             2.200534e+13
# 24                   2021-05-24             2.202452e+13
# ...                         ...                      ...
# 6                    2011-06-06             9.738557e+12
# 3                    2011-06-03             9.741263e+12
# 2                    2011-06-02             9.735617e+12
# 1                    2011-06-01             9.736529e+12
# 31                   2011-05-31             9.723456e+12
#
#                      Intragovernmental Holdings  \
# Calendar Day Number
# 28                                 6.178069e+12
# 27                                 6.179954e+12
# 26                                 6.181836e+12
# ...

# %%
dfpd.read_csv("USFR_BalSheet_10_years.csv")
# Out:
#     Record Date Account Description  \
# 0    2020-09-30              Assets
# 1    2020-09-30              Assets
# 2    2020-09-30              Assets
# 3    2020-09-30              Assets
# 4    2020-09-30              Assets
# ..          ...                 ...
# 250  2010-09-30         Liabilities
# 251  2010-09-30        Net position
# 252  2010-09-30        Net position
# 253  2010-09-30        Net position
# 254  2010-09-30        Net position
#
#                                 Line Item Description  \
# 0                      Cash and other monetary assets
# 1                            Accounts receivable, net
# 2    Direct loans and loan guarantees receivable, net
# 3               Inventories and related property, net
# 4          General property, plant and equipment, net
# ..                                                ...
# 250                                 Total liabilities
# 251                                   Earmarked funds
# ...

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
