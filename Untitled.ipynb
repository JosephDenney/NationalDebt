# %%
import pandas as pd
import numpy as np
pd.options.display.float_format= "{:.2f}".format

# %%
us_debt_by_day = pd.read_csv("DebtPenny_10_years.csv",index_col='Record Date')
us_debt_by_day = us_debt_by_day.drop(['Source Line Number','Fiscal Year','Fiscal Quarter Number',
                                      'Calendar Year','Calendar Quarter Number','Calendar Month Number',
                                      'Calendar Day Number'],axis='columns')
us_debt_by_day = us_debt_by_day.round()

# %%
us_debt_by_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2512 entries, 2021-05-28 to 2011-05-31
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Debt Held by the Public        2512 non-null   float64
#  1   Intragovernmental Holdings     2512 non-null   float64
#  2   Total Public Debt Outstanding  2512 non-null   float64
# dtypes: float64(3)
# memory usage: 78.5+ KB

# %%
us_debt_by_day
# Out:
#              Debt Held by the Public  Intragovernmental Holdings  \
# Record Date
# 2021-05-28         22020939013606.00            6178069324915.00
# 2021-05-27         21983687097488.00            6179954441120.00
# 2021-05-26         22005892292175.00            6181836272971.00
# 2021-05-25         22005337838702.00            6199345340521.00
# 2021-05-24         22024524562637.00            6189118887688.00
# ...                              ...                         ...
# 2011-06-06          9738557389966.00            4606100865261.00
# 2011-06-03          9741263236752.00            4603431155466.00
# 2011-06-02          9735616790662.00            4609089646380.00
# 2011-06-01          9736528968466.00            4608126997849.00
# 2011-05-31          9723456023744.00            4621212257467.00
#
#              Total Public Debt Outstanding
# Record Date
# 2021-05-28               28199008338521.00
# 2021-05-27               28163641538608.00
# 2021-05-26               28187728565146.00
# 2021-05-25               28204683179223.00
# 2021-05-24               28213643450325.00
# ...                                    ...
# 2011-06-06               14344658255227.00
# 2011-06-03               14344694392217.00
# 2011-06-02               14344706437042.00
# 2011-06-01               14344655966314.00
# 2011-05-31               14344668281211.00
#
# [2512 rows x 3 columns]

# %%
sorted_us_debt = us_debt_by_day.sort_index()

# %%
sorted_us_debt.plot(figsize=(20,10));

# %%
dfpd.read_csv("USFR_BalSheet_10_years.csv")
# Out:
#     Record Date Account Description  \
# 0    2020-09-30              Assets
# 1    2020-09-30              Assets
# 2    2020-09-30              Assets
# 3    2020-09-30              Assets
# 4    2020-09-30              Assets
# ..          ...                 ...
# 250  2010-09-30         Liabilities
# 251  2010-09-30        Net position
# 252  2010-09-30        Net position
# 253  2010-09-30        Net position
# 254  2010-09-30        Net position
#
#                                 Line Item Description  \
# 0                      Cash and other monetary assets
# 1                            Accounts receivable, net
# 2    Direct loans and loan guarantees receivable, net
# 3               Inventories and related property, net
# 4          General property, plant and equipment, net
# ..                                                ...
# 250                                 Total liabilities
# 251                                   Earmarked funds
# 252                               Non-earmarked funds
# 253                                Total net position
# 254                Total liabilities and net position
#
#      Position Amount (in Billions)  Source Line Number  Fiscal Year  \
# 0                           1926.9                   1         2020
# 1                            321.2                   2         2020
# 2                           1577.4                   3         2020
# 3                            379.7                   4         2020
# 4                           1145.0                   5         2020
# ..                             ...                 ...          ...
# 250                        16356.6                  21         2010
# 251                          646.9                  22         2010
# 252                       -14119.7                  23         2010
# 253                       -13472.8                  24         2010
# 254                         2883.8                  25         2010
#
#      Fiscal Quarter Number  Calendar Year  Calendar Quarter Number  \
# 0                        4           2020                        3
# 1                        4           2020                        3
# 2                        4           2020                        3
# 3                        4           2020                        3
# 4                        4           2020                        3
# ..                     ...            ...                      ...
# 250                      4           2010                        3
# 251                      4           2010                        3
# 252                      4           2010                        3
# 253                      4           2010                        3
# 254                      4           2010                        3
#
#      Calendar Month Number  Calendar Day Number
# 0                        9                   30
# 1                        9                   30
# 2                        9                   30
# 3                        9                   30
# 4                        9                   30
# ..                     ...                  ...
# 250                      9                   30
# 251                      9                   30
# 252                      9                   30
# 253                      9                   30
# 254                      9                   30
#
# [255 rows x 11 columns]

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
